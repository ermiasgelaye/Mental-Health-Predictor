# %% [markdown]
# # Loading mental helath data into Database
# * Reference the schema to create the schema in postgres
# * (make sure not add constraints to your schema before loading your data)
# #### Imports

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.pyplot as plot
from sqlalchemy import create_engine
from db_setup import pg_user, pg_password, db_name
import plotly.graph_objs as go

# %% [markdown]
# #### Connecting to the database

# %%
engine = create_engine('postgres://hbvrwvuwkcodfm:c7eb18f8d9d20e75348b1c7282058ab8272e92e58c255a9a7c86d57e2e88a3cc@ec2-52-203-165-126.compute-1.amazonaws.com:5432/d5djmd6ii028mk')

# %% [markdown]
# #### Checking table schema

# %%
engine.table_names()
# Out:
# ['mental_health', 'development_indicator']

# %% [markdown]
# #### Adding mental health data to schema

# %%
mental_helath_survey = '../survey.csv'
mental_helath_survey= pd.read_csv(mental_helath_survey , index_col=0)
mental_helath_survey
# Out:
#                    Age  Gender        Country state self_employed  \
# Timestamp
# 2014-08-27 12:03  27.0  Female  United States    NY           Yes
# 2014-08-27 22:55  30.0  Female  United States    WI           Yes
# 2014-08-27 12:11  29.0  Female  United States    FL            No
# 2014-08-27 12:15  25.0  Female         Canada   NaN            No
# 2014-08-27 12:44  25.0  Female  United States    NY            No
# ...                ...     ...            ...   ...           ...
# 2014-08-28 14:46  26.0     NaN        Germany   NaN           Yes
# 2014-08-27 14:22  30.0     NaN  United States    IL            No
# 2014-08-27 12:15  18.0     NaN         Russia   NaN            No
# 2014-08-28 9:02   19.0     NaN  United States    MO            No
# 2014-08-27 11:54  23.0     NaN  United States    MA            No
#
#                  family_history treatment work_interfere    no_employees  \
# Timestamp
# 2014-08-27 12:03             No       Yes          Often          05-Jan
# 2014-08-27 22:55            Yes       Yes          Often          05-Jan
# 2014-08-27 12:11             No       Yes      Sometimes          26-100
# 2014-08-27 12:15             No       Yes      Sometimes          26-100
# 2014-08-27 12:44            Yes       Yes      Sometimes        500-1000
# ...                         ...       ...            ...             ...
# 2014-08-28 14:46             No       Yes      Sometimes          25-Jun
# 2014-08-27 14:22            Yes       Yes         Rarely          26-100
# 2014-08-27 12:15             No        No            NaN          26-100
# 2014-08-28 9:02             Yes       Yes          Often          26-100
# 2014-08-27 11:54             No        No         Rarely  More than 1000
#
#                  remote_work  ...               leave  \
# Timestamp                     ...
# 2014-08-27 12:03         Yes  ...           Very easy
# 2014-08-27 22:55         Yes  ...  Somewhat difficult
# 2014-08-27 12:11          No  ...          Don't know
# 2014-08-27 12:15          No  ...          Don't know
# 2014-08-27 12:44          No  ...          Don't know
# ...                      ...  ...                 ...
# 2014-08-28 14:46         Yes  ...           Very easy
# 2014-08-27 14:22          No  ...       Somewhat easy
# 2014-08-27 12:15         Yes  ...       Somewhat easy
# 2014-08-28 9:02           No  ...  Somewhat difficult
# 2014-08-27 11:54          No  ...  Somewhat difficult
#
#                  mental_health_consequence phys_health_consequence  \
# Timestamp
# 2014-08-27 12:03                     Maybe                   Maybe
# 2014-08-27 22:55                        No                      No
# 2014-08-27 12:11                     Maybe                      No
# 2014-08-27 12:15                     Maybe                      No
# 2014-08-27 12:44                       Yes                     Yes
# ...                                    ...                     ...
# 2014-08-28 14:46                        No                      No
# 2014-08-27 14:22                     Maybe                      No
# 2014-08-27 12:15                        No                      No
# 2014-08-28 9:02                      Maybe                   Maybe
# 2014-08-27 11:54                     Maybe                      No
#
#                      coworkers    supervisor mental_health_interview  \
# Timestamp
# 2014-08-27 12:03  Some of them           Yes                      No
# 2014-08-27 22:55           Yes           Yes                      No
# 2014-08-27 12:11  Some of them  Some of them                      No
# 2014-08-27 12:15  Some of them           Yes                      No
# 2014-08-27 12:44  Some of them  Some of them                      No
# ...                        ...           ...                     ...
# 2014-08-28 14:46  Some of them  Some of them                   Maybe
# 2014-08-27 14:22  Some of them           Yes                      No
# 2014-08-27 12:15           Yes           Yes                     Yes
# 2014-08-28 9:02             No            No                      No
# 2014-08-27 11:54           Yes           Yes                      No
#
#                  phys_health_interview mental_vs_physical obs_consequence  \
# Timestamp
# 2014-08-27 12:03                 Maybe                Yes              No
# 2014-08-27 22:55                    No                Yes              No
# 2014-08-27 12:11                 Maybe                 No             Yes
# 2014-08-27 12:15                 Maybe         Don't know              No
# 2014-08-27 12:44                    No         Don't know              No
# ...                                ...                ...             ...
# 2014-08-28 14:46                 Maybe                Yes              No
# 2014-08-27 14:22                    No         Don't know              No
# 2014-08-27 12:15                   Yes         Don't know              No
# 2014-08-28 9:02                  Maybe                 No              No
# 2014-08-27 11:54                    No                 No              No
#
#                                                            comments
# Timestamp
# 2014-08-27 12:03                                                NaN
# 2014-08-27 22:55  Because I'm self-employed and the only person ...
# 2014-08-27 12:11                                                NaN
# 2014-08-27 12:15                                                NaN
# 2014-08-27 12:44                                                NaN
# ...                                                             ...
# 2014-08-28 14:46                                                NaN
# 2014-08-27 14:22                                                NaN
# 2014-08-27 12:15  In Russia we have mandatory medical insurance....
# 2014-08-28 9:02                                                 NaN
# 2014-08-27 11:54                                                NaN
#
# [1259 rows x 26 columns]

# %%
mental_helath_survey.to_sql(name='mental_health', con=engine, if_exists='append', index=True)

# %% [markdown]
# #### Adding  development indicator data to schema

# %%
development_indicator = '../clean_indicator.csv'
development_indicator= pd.read_csv(development_indicator , index_col=0)
development_indicator
# Out:
#            country_name country_code  social_insurance  social_protection  \
# 0           Afghanistan          AFG               NaN                NaN
# 1               Albania          ALB               NaN                NaN
# 2               Algeria          DZA               NaN                NaN
# 3        American Samoa          ASM               NaN                NaN
# 4               Andorra          AND               NaN                NaN
# ..                  ...          ...               ...                ...
# 258  West Bank and Gaza          PSE               NaN                NaN
# 259               World          WLD               NaN                NaN
# 260         Yemen, Rep.          YEM               NaN                NaN
# 261              Zambia          ZMB               NaN                NaN
# 262            Zimbabwe          ZWE          4.807448          36.742774
#
#      unemployment_benefits  Educational_attainment  Female_employment  \
# 0                      NaN                     NaN          23.177000
# 1                      NaN                     NaN          37.157101
# 2                      NaN                     NaN          12.350000
# 3                      NaN                     NaN                NaN
# 4                      NaN               96.534492                NaN
# ..                     ...                     ...                ...
# 258                    NaN                     NaN          10.611500
# 259                    NaN                     NaN                NaN
# 260                    NaN                     NaN                NaN
# 261                    NaN                     NaN                NaN
# 262               1.540269                     NaN          28.419600
#
#      Male_employment  GDP_per_capita(US$)  Labor_force_rate_female  ...  \
# 0          71.530197           613.856689                25.784300  ...
# 1          50.734901          4578.631994                43.983601  ...
# 2          60.139999          5493.025590                15.577800  ...
# 3                NaN         11507.232350                      NaN  ...
# 4                NaN         41303.929370                      NaN  ...
# ..               ...                  ...                      ...  ...
# 258        54.922401                  NaN                18.044001  ...
# 259              NaN         11428.569850                      NaN  ...
# 260              NaN                  NaN                      NaN  ...
# 261              NaN          1291.343357                      NaN  ...
# 262        44.281101          1463.985910                34.615200  ...
#
#      life_expectancy_female  Life_expectancy_total  Total_population  \
# 0                    64.453                 62.966      3.337079e+07
# 1                    80.045                 77.813      2.889104e+06
# 2                    77.085                 75.878      3.892369e+07
# 3                       NaN                    NaN      5.579100e+04
# 4                       NaN                    NaN      7.921300e+04
# ..                      ...                    ...               ...
# 258                     NaN                    NaN      4.685306e+06
# 259                     NaN                    NaN      7.673534e+09
# 260                     NaN                    NaN      2.916192e+07
# 261                     NaN                    NaN      1.786103e+07
# 262                     NaN                    NaN      1.464547e+07
#
#      Suicide_mortality_rate_per_100k  Suicide_mortality_rate_per_100k_female  \
# 0                                NaN                                     NaN
# 1                                NaN                                     NaN
# 2                                NaN                                     NaN
# 3                                NaN                                     NaN
# 4                                NaN                                     NaN
# ..                               ...                                     ...
# 258                              NaN                                     NaN
# 259                              NaN                                     NaN
# 260                              NaN                                     NaN
# 261                              NaN                                     NaN
# 262                              NaN                                     NaN
#
#      Suicide_mortality_rate_per_100k_male  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 258                                   NaN
# 259                                   NaN
# 260                                   NaN
# 261                                   NaN
# 262                                   NaN
#
#      unemployment_with_basic_education_total  \
# 0                                   7.380100
# 1                                  15.071700
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 258                                22.505501
# 259                                      NaN
# 260                                      NaN
# 261                                      NaN
# 262                                14.758000
#
#      Unemployment_with_basic_education_female  \
# 0                                     14.0912
# 1                                     10.7487
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 258                                   18.9575
# 259                                       NaN
# 260                                       NaN
# 261                                       NaN
# 262                                   15.1226
#
#      Unemployment_with_basic_education_male  Year
# 0                                  6.140500  2014
# 1                                 18.591000  2014
# 2                                       NaN  2014
# 3                                       NaN  2014
# 4                                       NaN  2014
# ..                                      ...   ...
# 258                               22.741699  2019
# 259                                     NaN  2019
# 260                                     NaN  2019
# 261                                     NaN  2019
# 262                               14.425500  2019
#
# [1578 rows x 24 columns]

# %%
development_indicator.to_sql(name='development_indicator', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-148b532d2bb9> in <module>
# ----> 1 development_indicator.to_sql(name='development_indicator', con=engine, if_exists='append', index=True)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     667         """
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#     671     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#     978             raise exc.ObjectNotExecutableError(object_)
#     979         else:
# --> 980             return meth(self, multiparams, params)
#     981
#     982     def _execute_function(self, func, multiparams, params):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     271     def _execute_on_connection(self, connection, multiparams, params):
#     272         if self.supports_execution:
# --> 273             return connection._execute_clauseelement(self, multiparams, params)
#     274         else:
#     275             raise exc.ObjectNotExecutableError(self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1097             distilled_params,
#    1098             compiled_sql,
# -> 1099             distilled_params,
#    1100         )
#    1101         if self._has_events or self.engine._has_events:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1238         except BaseException as e:
#    1239             self._handle_dbapi_exception(
# -> 1240                 e, statement, parameters, cursor, context
#    1241             )
#    1242
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1458                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1459             else:
# -> 1460                 util.reraise(*exc_info)
#    1461
#    1462         finally:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     275         if value.__traceback__ is not tb:
#     276             raise value.with_traceback(tb)
# --> 277         raise value
#     278
#     279
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1214                 if not evt_handled:
#    1215                     self.dialect.do_executemany(
# -> 1216                         cursor, statement, parameters, context
#    1217                     )
#    1218             elif not parameters and context.no_parameters:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     717             extras.execute_batch(cursor, statement, parameters)
#     718         else:
# --> 719             cursor.executemany(statement, parameters)
#     720
#     721     @util.memoized_instancemethod
#
# KeyError: 'GDP_per_capita(US$'
