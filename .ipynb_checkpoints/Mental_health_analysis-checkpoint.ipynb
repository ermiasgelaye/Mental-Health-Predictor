# %%
import os
from datetime import datetime
import numpy as np 
import pandas as pd
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
survey = pd.read_csv('Data/survey.csv')

# %%
survey.head()
# Out:
#           Timestamp   Age  Gender        Country state self_employed  \
# 0  2014-08-27 12:03  27.0  Female  United States    NY           Yes
# 1  2014-08-27 22:55  30.0  Female  United States    WI           Yes
# 2  2014-08-27 12:11  29.0  Female  United States    FL            No
# 3  2014-08-27 12:15  25.0  Female         Canada   NaN            No
# 4  2014-08-27 12:44  25.0  Female  United States    NY            No
#
#   family_history treatment work_interfere no_employees  ...  \
# 0             No       Yes          Often       05-Jan  ...
# 1            Yes       Yes          Often       05-Jan  ...
# 2             No       Yes      Sometimes       26-100  ...
# 3             No       Yes      Sometimes       26-100  ...
# 4            Yes       Yes      Sometimes     500-1000  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0           Very easy                     Maybe                   Maybe
# ...

# %% [markdown]
# # Data Cleaning

# %%
# removing columns not useful for our analysis
survey.drop(['Timestamp'], axis= 1,inplace = True)

# %%
# the NaN values of the "self_employed" column will be filled with the largely dominant value: "No"
survey['self_employed'].fillna('No',inplace = True)
survey['self_employed'].value_counts()
# Out:
# No     1113
# Yes     146
# Name: self_employed, dtype: int64

# %%
# Aggrigate value by gender
survey['Gender'].value_counts()
# Out:
# Male      993
# Female    249
# Name: Gender, dtype: int64

# %%
# changing "Yes" and "No" values by 1 and 0 (to make plots possible)
survey.replace(('Yes', 'No'), (1, 0), inplace=True)

# Gender versus treatment
gender_treatment= survey.pivot_table(index="Gender",values="treatment")
gender_treatment.plot.bar(figsize=(10,8),fontsize = 14)

plt.xlabel("Gender",fontsize = 14)
plt.ylabel("Proportion of people who sought treatment",fontsize = 14)
plt.title("Gender Versus Treatment",fontsize = 20)

plt.savefig("Image/gender_vs_treatment", bbox_inches = "tight")
plt.tight_layout()
plt.show()

# %%
# Replace NA values in work interfernce fild with"Don\'t know" 
survey['work_interfere'].fillna('Don\'t know', inplace = True)
survey['work_interfere'].value_counts()
# Out:
# Sometimes     465
# Don't know    264
# Never         213
# Rarely        173
# Often         144
# Name: work_interfere, dtype: int64

# %%
# Categorizing age to make ready for analysis
cut_points = [17,30,50,75]
label_names = ["Young Adult","Adult","Senior"]
survey["Age_categories"] = pd.cut(survey["Age"],cut_points,labels=label_names)

# %%
# plot treatmnet by age group
treatment_age = survey.pivot_table(index="Age_categories",values='treatment')
treatment_age.plot.bar(figsize=(10,8),fontsize = 14)

plt.xlabel("Age Group",fontsize = 14)
plt.ylabel("Proportion of people who sought treatment",fontsize = 14)
plt.title("Age Versus Treatment",fontsize = 20)

plt.savefig("Image/age_vs_treatment", bbox_inches = "tight")
plt.tight_layout()
plt.show()

# %%
survey["Age"].describe()
# Out:
# count    1259.000000
# mean       32.069897
# std         7.265565
# min        18.000000
# 25%        27.000000
# 50%        31.000000
# 75%        36.000000
# max        72.000000
# Name: Age, dtype: float64

# %%
# Some values in the "Age" column are not realistic or completely no sense (like negative values or positive values above 150).
#Values not between 18 and 73 will be filled by the median value of the column.
survey['Age'][survey['Age']<18] = survey['Age'].median()
survey['Age'][survey['Age']>73] = survey['Age'].median()

# %% [markdown]
# ## Normalizing the data for the ML Analysis

# %%
def create_dummies(df,column_name):
    dummies = pd.get_dummies(df[column_name],prefix=column_name)
    df = pd.concat([df,dummies],axis=1)
    return df
survey = create_dummies(survey,"Age_categories")
survey = create_dummies(survey,"Gender")

# creating dummy columns for other columns
cols = ['family_history','work_interfere', 'care_options','benefits', 'wellness_program','anonymity',\
        'leave','mental_health_consequence', 'phys_health_consequence']
for column in cols:
    survey = create_dummies(survey,column)
    
display(survey.head())
display(survey.shape)
survey.to_csv(path_or_buf="Normalized_df.csv")
# Out:
#     Age  Gender        Country state  self_employed  family_history  \
# 0  27.0  Female  United States    NY              1               0
# 1  30.0  Female  United States    WI              1               1
# 2  29.0  Female  United States    FL              0               0
# 3  25.0  Female         Canada   NaN              0               0
# 4  25.0  Female  United States    NY              0               1
#
#    treatment work_interfere no_employees  remote_work  ...  \
# 0          1          Often       05-Jan            1  ...
# 1          1          Often       05-Jan            1  ...
# 2          1      Sometimes       26-100            0  ...
# 3          1      Sometimes       26-100            0  ...
# 4          1      Sometimes     500-1000            0  ...
#
#    leave_Somewhat difficult leave_Somewhat easy leave_Very difficult  \
# 0                         0                   0                    0
# ...

# %%
# Try to see reletionships by ploting corroletion matrix
corrrelation=survey.corr()
corrrelation
# Out:
#                                       Age  self_employed  family_history  \
# Age                              1.000000       0.071318        0.009103
# self_employed                    0.071318       1.000000        0.009890
# family_history                   0.009103       0.009890        1.000000
# treatment                        0.073165       0.020493        0.377918
# remote_work                      0.145461       0.316533        0.014456
# ...                                   ...            ...             ...
# mental_health_consequence_1      0.056900      -0.016820        0.076716
# mental_health_consequence_Maybe  0.008039      -0.062977        0.022131
# phys_health_consequence_0       -0.098011      -0.023980       -0.049694
# phys_health_consequence_1        0.040613       0.056913        0.054299
# phys_health_consequence_Maybe    0.083841      -0.003964        0.024947
#
#                                  treatment  remote_work  tech_company  \
# ...

# %%
# plot the correlation matrix
corrMatrix=corrrelation.corr()
sns.heatmap(corrMatrix,annot=True)
plt.savefig("corrmatrix.png", bbox_inches="tight")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-114-d42c65079fea> in <module>
#       2 corrMatrix=corrrelation.corr()
#       3 sns.heatmap(corrMatrix,annot=True)
# ----> 4 plt.savefig("corrmatrix.png", bbox_inches="tight")
#       5 plt.show()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     728     fig = gcf()
#     729     res = fig.savefig(*args, **kwargs)
# --> 730     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     731     return res
#     732
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1914         if not self._is_idle_drawing:
#    1915             with self._idle_draw_cntx():
# -> 1916                 self.draw(*args, **kwargs)
#    1917
#    1918     def draw_cursor(self, event):
#
# ...

# %% [markdown]
# # Machine Learning Analysis

# %% [markdown]
# ## 1. Linear regression (+ classification by threshold)
